# %%
# !gdown "https://drive.google.com/uc?id=1bu_--mo79VdUG9oin4ybfFGRUSXAe-WE"
# !gdown "https://drive.google.com/uc?id=1IKuDizVapw-hyktwfpoAoaGtHtTNHfd0"
# !gdown "https://drive.google.com/uc?id=1saEqdbBB-vuk2hxoAf4TzDEsykdKlzbF"

import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer

# Load the datasets
customers = pd.read_csv('Customers.csv')
products = pd.read_csv('Products.csv')
transactions = pd.read_csv('Transactions.csv')

# Feature Engineering: Create a combined feature for each customer
merged_df = pd.merge(transactions, products, on='ProductID', how='left')
merged_df = pd.merge(merged_df, customers, on='CustomerID', how='left')

# Combine relevant features into a single string for each customer
merged_df['combined_features'] = merged_df['Region'] + ' ' + merged_df['Category'] + ' ' + merged_df['ProductName']
customer_features = merged_df.groupby('CustomerID')['combined_features'].apply(lambda x: ' '.join(x))


# TF-IDF Vectorization: Convert text features to numerical vectors
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(customer_features)

# Calculate Cosine Similarity: Find similar customers based on the vectors
cosine_sim = cosine_similarity(tfidf_matrix)


def recommend_customers(customer_id, cosine_sim_matrix, customer_features_df, top_n=3):
    """Recommends similar customers based on cosine similarity."""
    try:
        index = customer_features_df.index.get_loc(customer_id)
    except KeyError:
        print(f"Customer ID {customer_id} not found.")
        return []

    similarity_scores = list(enumerate(cosine_sim_matrix[index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)
    similarity_scores = similarity_scores[1:top_n + 1]  # Exclude the customer itself

    recommendations = []
    for index, score in similarity_scores:
        recommendations.append((customer_features_df.index[index], score))  # Return customer ID and score

    return recommendations

data = []
for x in range(20):
    customer_id_to_recommend = customers["CustomerID"].iloc[x]
    recommendations = recommend_customers(customer_id_to_recommend, cosine_sim, customer_features)

    print(f"Recommendations for customer {customer_id_to_recommend}:")
    for customer_id, score in recommendations:
        data.append({"custid": customer_id_to_recommend, "lookalike_custid": customer_id, "score": score})
        print(f"Customer ID: {customer_id}, Similarity Score: {score}")
    print()
pd.DataFrame(data).to_csv("Likitha_Baddepalli_Lookalike.csv", index=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1bu_--mo79VdUG9oin4ybfFGRUSXAe-WE
# To: /content/Customers.csv
# 100% 8.54k/8.54k [00:00<00:00, 26.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1IKuDizVapw-hyktwfpoAoaGtHtTNHfd0
# To: /content/Products.csv
# 100% 4.25k/4.25k [00:00<00:00, 14.0MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1saEqdbBB-vuk2hxoAf4TzDEsykdKlzbF
# To: /content/Transactions.csv
# 100% 54.7k/54.7k [00:00<00:00, 79.7MB/s]
# Recommendations for customer C0001:
# Customer ID: C0039, Similarity Score: 0.8965344367652105
# Customer ID: C0190, Similarity Score: 0.888469196466387
# Customer ID: C0096, Similarity Score: 0.887270644941772
#
# Recommendations for customer C0002:
# Customer ID: C0173, Similarity Score: 0.9129770184473479
# Customer ID: C0022, Similarity Score: 0.8841360179639877
# Customer ID: C0162, Similarity Score: 0.8449190544679047
#
# Recommendations for customer C0003:
# Customer ID: C0181, Similarity Score: 0.9055768454266909
# Customer ID: C0085, Similarity Score: 0.8938226899339604
# Customer ID: C0104, Similarity Score: 0.8883098011373014
#
# Recommendations for customer C0004:
# Customer ID: C0118, Similarity Score: 0.9413866751932005
# Customer ID: C0181, Similarity Score: 0.9248516293696559
# Customer ID: C0085, Similarity Score: 0.9034196415012151
#
# Recommendations for customer C0005:
# Customer ID: C0162, Similarity Score: 0.8738516333428844
# Customer ID: C0021, Similarity Score: 0.8524505393361899
# Customer ID: C0007, Similarity Score: 0.8519833541576461
#
# Recommendations for customer C0006:
# Customer ID: C0187, Similarity Score: 0.9232472021183894
# Customer ID: C0191, Similarity Score: 0.8789525368509676
# Customer ID: C0171, Similarity Score: 0.8582337416340726
#
# Recommendations for customer C0007:
# Customer ID: C0045, Similarity Score: 0.8856201262844334
# Customer ID: C0005, Similarity Score: 0.8519833541576461
# Customer ID: C0093, Similarity Score: 0.847971462244482
#
# Recommendations for customer C0008:
# Customer ID: C0154, Similarity Score: 0.927784088192308
# Customer ID: C0189, Similarity Score: 0.923615616599961
# Customer ID: C0122, Similarity Score: 0.9211016786665818
#
# Recommendations for customer C0009:
# Customer ID: C0062, Similarity Score: 0.8473357797808654
# Customer ID: C0105, Similarity Score: 0.8417873097377256
# Customer ID: C0114, Similarity Score: 0.79361061846087
#
# Recommendations for customer C0010:
# Customer ID: C0141, Similarity Score: 0.8330964902649897
# Customer ID: C0114, Similarity Score: 0.7850165463267241
# Customer ID: C0135, Similarity Score: 0.7682917899550643
#
# Recommendations for customer C0011:
# Customer ID: C0087, Similarity Score: 0.8971220549196876
# Customer ID: C0188, Similarity Score: 0.8920559087665443
# Customer ID: C0153, Similarity Score: 0.8860421755499731
#
# Recommendations for customer C0012:
# Customer ID: C0076, Similarity Score: 0.9340573838595541
# Customer ID: C0148, Similarity Score: 0.9135279679088415
# Customer ID: C0152, Similarity Score: 0.8982010423324387
#
# Recommendations for customer C0013:
# Customer ID: C0102, Similarity Score: 0.9381272731182405
# Customer ID: C0169, Similarity Score: 0.9093625553612161
# Customer ID: C0153, Similarity Score: 0.9055480690843613
#
# Recommendations for customer C0014:
# Customer ID: C0128, Similarity Score: 0.7285048594814186
# Customer ID: C0086, Similarity Score: 0.6975634629312273
# Customer ID: C0170, Similarity Score: 0.6785476968103823
#
# Recommendations for customer C0015:
# Customer ID: C0065, Similarity Score: 0.8845724412545668
# Customer ID: C0047, Similarity Score: 0.8819970969698023
# Customer ID: C0185, Similarity Score: 0.8744662350531638
#
# Recommendations for customer C0016:
# Customer ID: C0046, Similarity Score: 0.9003201908013605
# Customer ID: C0067, Similarity Score: 0.8897816978068864
# Customer ID: C0183, Similarity Score: 0.8705514227830098
#
# Recommendations for customer C0017:
# Customer ID: C0164, Similarity Score: 0.9192425083627697
# Customer ID: C0041, Similarity Score: 0.9082249881068161
# Customer ID: C0172, Similarity Score: 0.8746517931712054
#
# Recommendations for customer C0018:
# Customer ID: C0047, Similarity Score: 0.9434417057872995
# Customer ID: C0068, Similarity Score: 0.935475488804979
# Customer ID: C0156, Similarity Score: 0.9213101786683991
#
# Recommendations for customer C0019:
# Customer ID: C0070, Similarity Score: 0.9260291850888462
# Customer ID: C0075, Similarity Score: 0.8856336123126289
# Customer ID: C0057, Similarity Score: 0.8819193202614819
#
# Recommendations for customer C0020:
# Customer ID: C0050, Similarity Score: 0.9119960330278623
# Customer ID: C0026, Similarity Score: 0.8574650802191348
# Customer ID: C0068, Similarity Score: 0.8494384673294215
